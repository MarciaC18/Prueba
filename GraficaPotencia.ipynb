# %%
potencia = [0.97794, 0.89244, 0.87529, 0.86938]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(potencia, bins=10, range=(0.8, 1), color='blue', alpha=0.7)
plt.xlabel('Potencia')
plt.ylabel('Frecuencia')
plt.title('Distribución de Potencia de Compuestos')
plt.show()
plt.savefig('distribucion_potencia.png')
